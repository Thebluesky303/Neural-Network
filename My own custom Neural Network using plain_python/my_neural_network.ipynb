# %% [markdown]
# #

# %%
import kagglehub
path = kagglehub.dataset_download("lightningforpython/single-neuron-classification")
# Out:
# Using Colab cache for faster access to the 'single-neuron-classification' dataset.
